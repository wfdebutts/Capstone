# %%
import numpy as np
import pandas as pd
import csv

keys=pd.read_csv("adjData/popData.csv")
adjSet=pd.read_csv("adjData/nlist.csv")
keyList=keys[['GEOID']]
print('test')
# Out:
# test

# %%
# choose a starting discrict and start working 
# for test purposes we are going to make 1 district 24029950100
# could we precomput the number of districts that are adjcant to a disctric and each time they are added subract one -- much faster and
# we can search easily 

#globals
startTractId = 24029950100
targetPop=np.int64(721694)
adjacentSet = {}
first= [24029950100]
firstDpop=(keys[keys.GEOID == startTractId])[['POP100']].iloc[0]
foo=firstDpop >= targetPop
print(foo)

#function defs
def addTract( adjacent , tracts ):
    #Check to see if we are done 
    if (firstDpop >= targetPop).all():
        return [tracts]
    #see if there exists any orphonable districts 
    
    # else choose next district based on selection method 
    
    #update sets 
    
    #recursice call
    addTract(adjacent,tracts)

def updateAdjSet( key ):
    global adjacentSet 
    toAdd = adjSet[adjSet.SOURCE_TRACTID == key] # adjacent tracts for census tracts key in NEIGHBOR_TRACTID col 
    print (toAdd)
    return 

updateAdjSet(key=startTractId)   
print (addTract(adjacent=adjacentSet,tracts=first))
print(firstDpop.dtype)
print(targetPop.dtype)
# Out:
# POP100    False
# Name: 648, dtype: bool
#               Noise  SOURCE_TRACTID  NEIGHBOR_TRACTID
# 193503  24029950100     24029950100       10001040100
# 193504  24029950100     24029950100       10003016801
# 193505  24029950100     24029950100       10003016901
# 193506  24029950100     24029950100       24015030100
# 193507  24029950100     24029950100       24029950200
# 193508  24029950100     24029950100       24035810100
# 193509  24029950100     24029950100       24035810200
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-00c2513ac4cb> in <module>()
#      31     return
#      32 updateAdjSet(key=startTractId)
# ---> 33 print (addTract(adjacent=adjacentSet,tracts=first))
#      34 print(firstDpop.dtype)
#      35 print(targetPop.dtype)
#
# <ipython-input-44-00c2513ac4cb> in addTract(adjacent, tracts)
#      23
#      24     #recursice call
# ...

# %%
for i in range(1, keyList.shape[0]):
    key = keyList.iloc[i]['GEOID']
    foo = adjSet[adjSet.SOURCE_TRACTID == key] # adjacent tracts for census tracts key in NEIGHBOR_TRACTID col

# %%
adjSet.dtypes
# Out:
# Noise               int64
# SOURCE_TRACTID      int64
# NEIGHBOR_TRACTID    int64
# dtype: object
